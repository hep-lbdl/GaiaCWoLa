# %%
# %load_ext autoreload
# %autoreload 2

# %%
from functions import *

# %%
df = load_file(stream = "gd1_tail", percent_bkg = 10)
# Out:
# 100%|███████████████████████████████████████████████████████| 1985/1985 [01:35<00:00, 20.73it/s]
# Before reduction, stream stars make up 0.038% of the dataset.
# After reduction, stream stars make up 0.383% of the dataset.

# %%
visualize_stream(df)
