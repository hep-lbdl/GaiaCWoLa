# %%
# %load_ext autoreload
# %autoreload 2

# %%
from functions import *

# %%
file = get_random_file()
df = load_file(file, stream = "mock", percent_bkg = 10)
# Out:
# Before reduction, stream stars make up 0.042% of the dataset.
# After reduction, stream stars make up 0.414% of the dataset.

# %%
df.shape
# Out:
# (45164, 11)

# %%
df
# Out:
#               μ_δ       μ_α          δ           α       mag      color  \
# 1522    -5.839800 -2.362100  57.752429  171.150213  1.753700  18.649500
# 1543    15.785900 -8.076680  57.629828  171.124618  1.239901  18.077200
# 1551   -12.900700 -1.219960  57.570133  170.872213  1.054001  17.506701
# 1554    -1.632930 -0.175915  57.539805  170.823469  0.254501  18.636499
# 1560    -3.564820  0.170506  57.515034  171.184321  0.650499  20.606899
# ...           ...       ...        ...         ...       ...        ...
# 886128  -0.496671  1.270276  62.727529  153.284674  0.165271  20.689260
# 886130  -1.534768  3.122079  64.068124  157.923974  0.314122  20.631624
# 886131  -1.726999  2.113136  65.835638  166.088526  0.234678  20.541554
# 886138  -1.667703  2.693200  60.527517  149.468239  0.568818  20.180136
# 886139  -0.761536  1.985084  57.655997  143.824116  1.897030  20.489869
#
#                a         b          c          d  stream
# ...
